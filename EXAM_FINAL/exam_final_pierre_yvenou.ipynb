# %%
# Imports
import numpy as np
import pandas as pd
# Sources (CSV)
historical_performance_csv = 'test_portfolio.csv'
# Load historical performance data
historical_data = pd.read_csv(historical_performance_csv, parse_dates=[''], index_col='')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Imports
# ----> 2 import numpy as np
#       3 import pandas as pd
#       4 # Sources (CSV)
#
# ModuleNotFoundError: No module named 'numpy'

# %%
historical_data.head(10)
